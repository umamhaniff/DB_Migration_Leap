# %% [markdown]
# # 🔍 Check Pickle Data
#
# Gunakan notebook ini untuk memeriksa isi file hasil transformasi.

# %% [markdown]
# ### 1. Lihat Daftar File
# Jalankan cell di bawah ini untuk melihat daftar file yang tersedia.

# %%
from glob import glob
import os

# Scan semua file pickle
pickle_files = glob('**/*.pkl', recursive=True)
print("Daftar file yang bisa kamu periksa:")
print("-" * 40)
for i, f in enumerate(pickle_files):
    print(f"[{i}] {f}")
print("-" * 40)
print("Silakan pilih nomor index untuk digunakan di Cell 2.")
# Out:
# Daftar file yang bisa kamu periksa:
# ----------------------------------------
# [0] fase_1\fase_1_afrida.pkl
# [1] fase_1\fase_1_cimut.pkl
# [2] fase_2\fase_2_afrida.pkl
# [3] fase_3\fase_3_hanif.pkl
# [4] fase_4\fase_4_hanif.pkl
# [5] fase_5\fase_5_hanif.pkl
# ----------------------------------------
# Silakan pilih nomor index untuk digunakan di Cell 2.

# %% [markdown]
# ### 2. Tampilkan Isi File
# Ganti nilai `pilih_index` dengan nomor yang kamu inginkan, lalu jalankan cell ini.

# %%
import pickle
import pandas as pd

pilih_index = 0  # <--- GANTI ANGKA INI SESUAI PILIHANMU

if 'pickle_files' in locals() and 0 <= pilih_index < len(pickle_files):
    target_path = pickle_files[pilih_index]
    print(f"📂 Membuka file: {target_path}\n")
    
    try:
        with open(target_path, "rb") as f:
            data = pickle.load(f)
        
        if isinstance(data, dict):
            print(f"✅ Berhasil! Ditemukan {len(data)} tabel.\n")
            for table_name, df in data.items():
                print(f"📌 Tabel: {table_name} ({len(df)} baris)")
                if hasattr(df, 'head') and not df.empty:
                    display(df.head())
                elif df.empty:
                    print("   ⚠️ Tabel ini kosong")
        else:
            print("Data bukan format dictionary, berikut isinya:")
            print(data)
            
    except NotImplementedError:
        print("❌ ERROR: File ini masih pakai tipe data 'StringDtype' yang bermasalah di Python 3.13.")
        print("💡 SOLUSI: Jalankan ulang script transformasinya dulu agar filenya diperbarui ke format aman.")
    except Exception as e:
        print(f"❌ Gagal membuka file: {e}")
else:
    print("❌ Index tidak valid atau Cell 1 belum dijalankan!")
# Out:
# 📂 Membuka file: fase_1\fase_1_afrida.pkl
#
# ✅ Berhasil! Ditemukan 7 tabel.
#
# 📌 Tabel: kursus (21 baris)
#   id_kursus             nama_kursus                       deskripsi
# 0    K00001  LEAP - General English  GE, Balloons, Gogo, SO, Winner
# 1    K00002     LEAP - Coding Class            Coding Class Regular
# 📌 Tabel: level (181 baris)
#   id_level   nama_level  urutan_level
# 0   L00001  Balloons 1A             1
# 1   L00002  Balloons 1B             2
# 📌 Tabel: sesi (43 baris)
#   id_sesi      nama_sesi waktu_mulai waktu_selesai
# 0  S00001  GE/LLC Sesi 1    15:45:00      16:45:00
# 1  S00002  GE/LLC Sesi 2    17:00:00      18:00:00
# 📌 Tabel: libur (79 baris)
#   id_libur      nama_event tanggal_mulai tanggal_berakhir deskripsi_libur  \
# 0   L00005  Libur Nasional    2023-07-19       2023-07-20
# 1   L00006  Libur Nasional    2023-06-29       2023-06-30
#
#   sumber label_warna  status_libur_program
# 0                                        1
# 1                                        1
# 📌 Tabel: topik_diskusi (11 baris)
#   id_topik_diskusi  topik_diskusi deskripsi_topik_diskusi
# 0             None  Kendala Siswa
# 1             None  Kendala Kelas
# 📌 Tabel: kursus_level (181 baris)
#   id_kursus id_level
# 0    K00001   L00001
# 1    K00001   L00002
# 📌 Tabel: kursus_libur (2 baris)
#   id_kursus id_libur
# 0    K00001   L00070
# 1    K00001   L00068
