# %%
import sys
import os
import mysql.connector
import pandas as pd
sys.path.append(os.path.abspath('..'))
from config import get_db_config
import warnings
warnings.filterwarnings('ignore')
import json
import pickle
import numpy as np
import datetime
from IPython.display import display, HTML

# %%
# Connect ke database config
config = get_db_config()
# Ambil host dari salah satu config (misal db_old)
print(f'Database config loaded: {config["db_old"]["host"]}')

# Connect ke DB Lama
db_old = mysql.connector.connect(**config['db_old'])
cursor_old = db_old.cursor(dictionary=True)
print(f'Connected to old database: {config["db_old"]["database"]}')

# Connect ke DB Baru
db_new = mysql.connector.connect(**config['db_new'])
cursor_new = db_new.cursor(dictionary=True)
print(f'Connected to new database: {config["db_new"]["database"]}')

db_future = mysql.connector.connect(**config['db_future'])
cursor_future = db_future.cursor(dictionary=True)
print(f'Connected to future database: {config["db_future"]["database"]}')
# Out:
# Database config loaded: localhost
# Connected to old database: dataleap_v5_example
# Connected to new database: 9
# Connected to future database: 9

# %% [markdown]
# ## Hide code

# %%
import pickle
import os

print("================================================================================")
print(" 🚀 SETUP INSERT HANDLER - FASE 1 (SISTEM MULTI-OWNER & AUTO-MAP) 🚀 ")
print("================================================================================")

# ================================================================================
# KONFIGURASI 1: LOAD MASING-MASING FILE PICKLE (TETAP TERPISAH)
# ================================================================================
data_cimut = {}
data_afrida = {}
data_hanif = {}

# 1. Load File cimut (Ganti nama file sesuai punyamu)
try:
    with open('fase_3_cimut.pkl', 'rb') as f:
        data_cimut = pickle.load(f)
    print("✓ Berhasil memuat data PKL milik cimut.")
except Exception as e:
    print(f"⚠️ Peringatan: Gagal memuat file pkl cimut: {e}")

# 2. Load File Afrida
try:
    with open('fase_3_afrida.pkl', 'rb') as f:
        data_afrida = pickle.load(f)
    print("✓ Berhasil memuat data PKL milik Afrida.")
except Exception as e:
    print(f"⚠️ Peringatan: Gagal memuat file pkl Afrida: {e}")

# 3. Load File Hanif
try:
    with open('fase_3_hanif.pkl', 'rb') as f:
        data_hanif = pickle.load(f)
    print("✓ Berhasil memuat data PKL milik Hanif.")
except Exception as e:
    print(f"⚠️ Peringatan: Gagal memuat file pkl Hanif: {e}")

print("\n================================================================================")
# ================================================================================
# KONFIGURASI 2: ISI DAFTAR TABEL MILIK MASING-MASING ORANG
# ================================================================================
list_table_cimut = [
    "kontak_prospek",
    "calon_siswa",
    "calon_siswa_akademik",
    "calon_siswa_ortu",
    "calon_siswa_bayar",
    "calon_siswa_jadwal",
    "calon_siswa_kursus",
    "calon_siswa_proses",
    "calon_siswa_status_logs",
    "peminjaman",
    "pengadaan",
    "problem",
]

list_table_afrida = [
    "sop",
    "surat_keluar",
    "verifikasi_surat_keluar",
    "surat_tugas",
    "surat_tugas_anggota",
    "sop_kategori",
]

list_table_hanif = [
    "pengajuan_karyawan",
    "histori_pengajuan",
    "pelamar",
    "pelamar_kerja",
    "pelamar_sekolah",
    "pelamar_kursus",
    "progres_pelamar",
    "rekrutmen_pelamar",
]

# ================================================================================
# KONFIGURASI 3: ATUR URUTAN MUTLAK PENYUNTIKAN KE DATABASE (MASTER ORDER)
# ================================================================================
# Masukkan nama tabel yang mau di-insert sesuai urutan FK (Foreign Key).
# Kamu bebas menyilangkan nama tabel di sini, sistem akan otomatis mencari pemiliknya.
master_urutan_insert = [
    "kontak_prospek",
    "calon_siswa",
    "calon_siswa_akademik",
    "calon_siswa_ortu",
    "calon_siswa_bayar",
    "calon_siswa_jadwal",
    "calon_siswa_kursus",
    "calon_siswa_proses",
    "calon_siswa_status_logs",
    "peminjaman",
    "pengadaan",
    "problem",
    "sop",
    "surat_keluar",
    "verifikasi_surat_keluar",
    "surat_tugas",
    "surat_tugas_anggota",
    "sop_kategori",
    "pengajuan_karyawan",
    "histori_pengajuan",
    "pelamar",
    "pelamar_kerja",
    "pelamar_sekolah",
    "pelamar_kursus",
    "progres_pelamar",
    "rekrutmen_pelamar",
]

# ================================================================================
# SISTEM DETEKTIF: MENCARI DAN MENGGABUNGKAN DATA BERDASARKAN PEMILIKNYA
# ================================================================================
print("🔍 Memulai proses pemetaan tabel ke pemilik masing-masing...\n")

data_siap_insert = {}

for table in master_urutan_insert:
    if table in list_table_cimut:
        data_siap_insert[table] = data_cimut.get(table)
        print(f"  📦 Tabel '{table}' otomatis dipetakan dari data cimut.")
        
    elif table in list_table_afrida:
        data_siap_insert[table] = data_afrida.get(table)
        print(f"  📦 Tabel '{table}' otomatis dipetakan dari data Afrida.")
        
    elif table in list_table_hanif:
        data_siap_insert[table] = data_hanif.get(table)
        print(f"  📦 Tabel '{table}' otomatis dipetakan dari data Hanif.")
        
    else:
        # Jika kamu memasukkan nama tabel di master_urutan tapi lupa memasukkannya di list pemilik
        data_siap_insert[table] = None
        print(f"  ❌ ERROR: Tabel '{table}' tidak ada di list cimut, Afrida, maupun Hanif!")

print("\n✅ Pemetaan selesai! Data siap disuntikkan ke database.")
# Out:
# ================================================================================
#  🚀 SETUP INSERT HANDLER - FASE 1 (SISTEM MULTI-OWNER & AUTO-MAP) 🚀
# ================================================================================
# ✓ Berhasil memuat data PKL milik cimut.
# ✓ Berhasil memuat data PKL milik Afrida.
# ✓ Berhasil memuat data PKL milik Hanif.
#
# ================================================================================
# 🔍 Memulai proses pemetaan tabel ke pemilik masing-masing...
#
#   📦 Tabel 'kontak_prospek' otomatis dipetakan dari data cimut.
#   📦 Tabel 'calon_siswa' otomatis dipetakan dari data cimut.
#   📦 Tabel 'calon_siswa_akademik' otomatis dipetakan dari data cimut.
#   📦 Tabel 'calon_siswa_ortu' otomatis dipetakan dari data cimut.
#   📦 Tabel 'calon_siswa_bayar' otomatis dipetakan dari data cimut.
#   📦 Tabel 'calon_siswa_jadwal' otomatis dipetakan dari data cimut.
#   📦 Tabel 'calon_siswa_kursus' otomatis dipetakan dari data cimut.
#   📦 Tabel 'calon_siswa_proses' otomatis dipetakan dari data cimut.
#   📦 Tabel 'calon_siswa_status_logs' otomatis dipetakan dari data cimut.
#   📦 Tabel 'peminjaman' otomatis dipetakan dari data cimut.
#   📦 Tabel 'pengadaan' otomatis dipetakan dari data cimut.
#   📦 Tabel 'problem' otomatis dipetakan dari data cimut.
#   📦 Tabel 'sop' otomatis dipetakan dari data Afrida.
#   📦 Tabel 'surat_keluar' otomatis dipetakan dari data Afrida.
#   📦 Tabel 'verifikasi_surat_keluar' otomatis dipetakan dari data Afrida.
#   📦 Tabel 'surat_tugas' otomatis dipetakan dari data Afrida.
#   📦 Tabel 'surat_tugas_anggota' otomatis dipetakan dari data Afrida.
#   📦 Tabel 'sop_kategori' otomatis dipetakan dari data Afrida.
#   📦 Tabel 'pengajuan_karyawan' otomatis dipetakan dari data Hanif.
#   📦 Tabel 'histori_pengajuan' otomatis dipetakan dari data Hanif.
#   📦 Tabel 'pelamar' otomatis dipetakan dari data Hanif.
#   📦 Tabel 'pelamar_kerja' otomatis dipetakan dari data Hanif.
#   📦 Tabel 'pelamar_sekolah' otomatis dipetakan dari data Hanif.
#   📦 Tabel 'pelamar_kursus' otomatis dipetakan dari data Hanif.
#   📦 Tabel 'progres_pelamar' otomatis dipetakan dari data Hanif.
#   📦 Tabel 'rekrutmen_pelamar' otomatis dipetakan dari data Hanif.
#
# ✅ Pemetaan selesai! Data siap disuntikkan ke database.

# %% [markdown]
# ## Hide code

# %%
import pandas as pd
import datetime
import numpy as np
import mysql.connector

# ================================================================================
# TAHAP 3: FUNGSI UTAMA INSERT (ANTI SILENT-KILLER, AUTO-BATCHING & DIAGNOSTIC)
# ================================================================================
def insert_data_with_preview_and_skip_v2(db_connection, cursor, tables_data, ordered_list, batch_size=2000):
    results = {}
    
    print("="*80)
    print("🎬 MEMULAI EKSEKUSI PENYUNTIKAN DATA KE MYSQL BARU (SISTEM AUTO-BATCHING)")
    print("="*80)
    
    # ----------------------------------------------------------------------------
    # SUB-LANGKAH A: PROSES INSERT KE MYSQL DENGAN CHUNKING (LOOPING AMAN)
    # ----------------------------------------------------------------------------
    for table_name in ordered_list:
        if table_name not in tables_data:
            results[table_name] = {'status': 'not_found', 'msg': f'⚠️  {table_name}: Tidak ditemukan di file pkl', 'warnings': []}
            continue
            
        df_target = tables_data[table_name]
        
        if df_target is None or df_target.empty:
            results[table_name] = {'status': 'empty', 'msg': f'ℹ️  {table_name}: DataFrame kosong (0 baris)', 'warnings': []}
            continue
            
        try:
            # Bersihkan kolom kosong murni
            df_to_push = df_target.dropna(axis=1, how='all')
            columns_str = ', '.join([f'`{col}`' for col in df_to_push.columns])
            placeholders_str = ', '.join(['%s'] * len(df_to_push.columns))
            
            insert_query = f"INSERT IGNORE INTO `{table_name}` ({columns_str}) VALUES ({placeholders_str})"
            
            raw_numpy_list = df_to_push.to_numpy().tolist()
            
            # TUPLE GENERATOR (Mempertahankan "" untuk kolom Varchar NOT NULL)
            clean_data_tuples = [
                tuple(None if pd.isna(x) or str(x).strip() in ["NaT", "NaN"] else x for x in row) 
                for row in raw_numpy_list
            ]
            
            total_rows = len(clean_data_tuples)
            actual_inserted_total = 0
            db_warnings = []
            
            # 🔥 SISTEM AUTO-BATCHING (CHUNKING) 🔥
            # Loop memotong data menjadi bagian-bagian kecil agar MySQL tidak tersedak
            for i in range(0, total_rows, batch_size):
                chunk = clean_data_tuples[i : i + batch_size]
                cursor.executemany(insert_query, chunk)
                
                # Hitung data yang berhasil masuk pada batch ini
                chunk_inserted = max(0, cursor.rowcount)
                actual_inserted_total += chunk_inserted
                
                # Jika ada yang ter-skip di batch ini, tangkap errornya (maksimal simpan 3 per tabel)
                if chunk_inserted < len(chunk) and len(db_warnings) < 10:
                    cursor.execute("SHOW WARNINGS")
                    warnings_fetched = cursor.fetchall()
                    if warnings_fetched:
                        for w in warnings_fetched:
                            w_msg = f"MySQL Warning: {w['Message']}"
                            if w_msg not in db_warnings:
                                db_warnings.append(w_msg)
                            if len(db_warnings) >= 3:
                                break
                                
                # Commit per batch agar memori stabil
                db_connection.commit()
            
            # Evaluasi Status Akhir Tabel
            if actual_inserted_total == total_rows:
                status_flag = 'success'
                msg = f'✓ {table_name}: SEMPURNA! {total_rows}/{total_rows} baris sukses masuk database.'
            else:
                status_flag = 'partial_warning'
                msg = f'⚠️ {table_name}: TER-SKIP! Dikirim {total_rows} baris, tapi yang masuk DB HANYA {actual_inserted_total} baris.'

            results[table_name] = {
                'status': status_flag, 
                'msg': msg,
                'warnings': db_warnings
            }
            
        except Exception as e:
            db_connection.rollback()
            results[table_name] = {
                'status': 'failed', 
                'msg': f'✗ {table_name}: Gagal total saat eksekusi insert - Alasan: {e}',
                'warnings': []
            }

    # ----------------------------------------------------------------------------
    # 📊 CETAK PAPAN RINGKASAN DI PALING ATAS (SUMMARY BOARD)
    # ----------------------------------------------------------------------------
    print("\n================================================================================")
    print(" 📊 PAPAN RINGKASAN STATUS MIGRATION DATA (SUMMARY BOARD) 📊")
    print("================================================================================")
    
    print("🟢 TABEL YANG 100% SUKSES MASUK:")
    success_exist = False
    for table_name in ordered_list:
        res = results.get(table_name, {})
        if res.get('status') == 'success':
            print(f"  {res['msg']}")
            success_exist = True
    if not success_exist: print("  (Tidak ada tabel yang sukses sempurna)")

    print("\n🔴 TABEL YANG BERMASALAH / TER-SKIP (WAJIB DI CEK!):")
    failed_exist = False
    for table_name in ordered_list:
        res = results.get(table_name, {})
        if res.get('status') in ['failed', 'partial_warning', 'not_found', 'empty']:
            print(f"  {res['msg']}")
            
            # Cetak alasan dari MySQL (Dibatasi 3 agar tidak merusak tampilan Jupyter)
            if res.get('warnings'):
                for w_msg in res['warnings']:
                    print(f"      -> 🕵️ {w_msg}")
                    
            failed_exist = True
            
    if not failed_exist: print("  🎉 LUAR BIASA! Semua tabel bersih tidak ada data yang terbuang.")
            
    print("================================================================================\n")

    # ----------------------------------------------------------------------------
    # 📸 CETAK PREVIEW HISTORI & DIAGNOSTIK ERROR DI BAGIAN BAWAH
    # ----------------------------------------------------------------------------
    print("="*80)
    print("📸 MEMULAI LOG VISUALISASI PREVIEW & DIAGNOSTIK TABEL")
    print("="*80)
    
    for table_name in ordered_list:
        if table_name in results:
            res = results[table_name]
            
            if res['status'] == 'success':
                print(f"\n📂 [🟢 PREVIEW TABEL SUKSES: {table_name.upper()}]")
                print("-" * 50)
                display(tables_data[table_name].head(3))
                print("-" * 80)
                
            elif res['status'] in ['failed', 'partial_warning']:
                print(f"\n🚨 [🔴 DIAGNOSTIK TABEL ERROR: {table_name.upper()}] 🚨")
                print(f"Pesan Sistem: {res['msg']}")
                print("-" * 50)
                print("Berikut cuplikan data yang kemungkinan ditolak MySQL (Cek FK dan Tipe Data):")
                display(tables_data[table_name].head(5))
                print(f"\nTipe data Pandas untuk tabel '{table_name}':")
                print(tables_data[table_name].dtypes)
                print("-" * 80)
            
    print("\n" + "="*80)
    print("🏁 PROSES INSPEKSI SELESAI. SILAKAN CEK HASIL DIAGNOSTIK DI ATAS 🏁")
    print("="*80)
    return results

# %% [markdown]
# ## Output

# %%
# ================================================================================
# TAHAP 4: MENJALANKAN EKSEKUSI DATA REAL
# ================================================================================
results_fase_3 = insert_data_with_preview_and_skip_v2(
    db_connection=db_future, 
    cursor=cursor_future, 
    tables_data=data_siap_insert,       # <--- Menggunakan data yang sudah di-mapping otomatis
    ordered_list=master_urutan_insert   # <--- Menggunakan urutan master buatanmu
)
# Out:
# ================================================================================
# 🎬 MEMULAI EKSEKUSI PENYUNTIKAN DATA KE MYSQL BARU (SISTEM AUTO-BATCHING)
# ================================================================================
#
# ================================================================================
#  📊 PAPAN RINGKASAN STATUS MIGRATION DATA (SUMMARY BOARD) 📊
# ================================================================================
# 🟢 TABEL YANG 100% SUKSES MASUK:
#   ✓ kontak_prospek: SEMPURNA! 194/194 baris sukses masuk database.
#   ✓ calon_siswa: SEMPURNA! 166/166 baris sukses masuk database.
#   ✓ calon_siswa_akademik: SEMPURNA! 166/166 baris sukses masuk database.
#   ✓ calon_siswa_ortu: SEMPURNA! 166/166 baris sukses masuk database.
#   ✓ calon_siswa_bayar: SEMPURNA! 166/166 baris sukses masuk database.
#   ✓ calon_siswa_jadwal: SEMPURNA! 166/166 baris sukses masuk database.
#   ✓ calon_siswa_kursus: SEMPURNA! 166/166 baris sukses masuk database.
#   ✓ calon_siswa_proses: SEMPURNA! 166/166 baris sukses masuk database.
#   ✓ peminjaman: SEMPURNA! 194/194 baris sukses masuk database.
#   ✓ pengadaan: SEMPURNA! 110/110 baris sukses masuk database.
#   ✓ problem: SEMPURNA! 160/160 baris sukses masuk database.
#   ✓ surat_keluar: SEMPURNA! 213/213 baris sukses masuk database.
#   ✓ verifikasi_surat_keluar: SEMPURNA! 477/477 baris sukses masuk database.
#   ✓ surat_tugas: SEMPURNA! 135/135 baris sukses masuk database.
#   ✓ sop_kategori: SEMPURNA! 2/2 baris sukses masuk database.
#   ✓ pengajuan_karyawan: SEMPURNA! 33/33 baris sukses masuk database.
#   ✓ histori_pengajuan: SEMPURNA! 79/79 baris sukses masuk database.
#   ✓ pelamar_kerja: SEMPURNA! 67/67 baris sukses masuk database.
#
# 🔴 TABEL YANG BERMASALAH / TER-SKIP (WAJIB DI CEK!):
#   ℹ️  calon_siswa_status_logs: DataFrame kosong (0 baris)
#   ⚠️ sop: TER-SKIP! Dikirim 4 baris, tapi yang masuk DB HANYA 0 baris.
#       -> 🕵️ MySQL Warning: Cannot add or update a child row: a foreign key constraint fails (`9`.`sop`, CONSTRAINT `sop_id_sop_kategori_foreign` FOREIGN KEY (`id_sop_kategori`) REFERENCES `sop_kategori` (`id_sop_kategori`))
#   ⚠️ surat_tugas_anggota: TER-SKIP! Dikirim 304 baris, tapi yang masuk DB HANYA 260 baris.
#       -> 🕵️ MySQL Warning: Cannot add or update a child row: a foreign key constraint fails (`9`.`surat_tugas_anggota`, CONSTRAINT `surat_tugas_anggota_id_st_foreign` FOREIGN KEY (`id_st`) REFERENCES `surat_tugas` (`id_st`) ON DELETE SET NULL)
#   ⚠️ pelamar: TER-SKIP! Dikirim 192 baris, tapi yang masuk DB HANYA 142 baris.
#       -> 🕵️ MySQL Warning: Out of range value for column 'created_at' at row 1
#       -> 🕵️ MySQL Warning: Incorrect integer value: 'asd' for column `9`.`pelamar`.`skor_toefl` at row 3
#       -> 🕵️ MySQL Warning: Out of range value for column 'created_at' at row 3
#   ⚠️ pelamar_sekolah: TER-SKIP! Dikirim 53 baris, tapi yang masuk DB HANYA 51 baris.
#       -> 🕵️ MySQL Warning: Cannot add or update a child row: a foreign key constraint fails (`9`.`pelamar_sekolah`, CONSTRAINT `pelamar_sekolah_id_pelamar_foreign` FOREIGN KEY (`id_pelamar`) REFERENCES `pelamar` (`id_pelamar`))
#   ⚠️ pelamar_kursus: TER-SKIP! Dikirim 50 baris, tapi yang masuk DB HANYA 49 baris.
#       -> 🕵️ MySQL Warning: Cannot add or update a child row: a foreign key constraint fails (`9`.`pelamar_kursus`, CONSTRAINT `pelamar_kursus_id_pelamar_foreign` FOREIGN KEY (`id_pelamar`) REFERENCES `pelamar` (`id_pelamar`))
#   ⚠️ progres_pelamar: TER-SKIP! Dikirim 403 baris, tapi yang masuk DB HANYA 304 baris.
#       -> 🕵️ MySQL Warning: Cannot add or update a child row: a foreign key constraint fails (`9`.`progres_pelamar`, CONSTRAINT `progres_pelamar_id_pelamar_foreign` FOREIGN KEY (`id_pelamar`) REFERENCES `pelamar` (`id_pelamar`))
#   ⚠️ rekrutmen_pelamar: TER-SKIP! Dikirim 281 baris, tapi yang masuk DB HANYA 215 baris.
#       -> 🕵️ MySQL Warning: Cannot add or update a child row: a foreign key constraint fails (`9`.`rekrutmen_pelamar`, CONSTRAINT `rekrutmen_pelamar_id_pelamar_foreign` FOREIGN KEY (`id_pelamar`) REFERENCES `pelamar` (`id_pelamar`))
# ================================================================================
#
# ================================================================================
# 📸 MEMULAI LOG VISUALISASI PREVIEW & DIAGNOSTIK TABEL
# ================================================================================
#
# 📂 [🟢 PREVIEW TABEL SUKSES: KONTAK_PROSPEK]
# --------------------------------------------------
#    id_kontak_prospek kode_kontak             nama_penanya nomor_telepon  \
# 0                  1    PIJWREZC     Daria Azmiya Jasmine  082231346758
# 1                  2    LEHUEB6B  Annisa Zahro Ramadhania  081336647476
# 2                  3    HBJ6O8TF     Zulfa Bariatur Rahma  085707179656
#
#                        email       sumber_informasi catatan_awal_fo  \
# 0  puterihapsari.f@gmail.com  Teman/kerabat/saudara            None
# 1         dwirohm4@gmail.com              Instagram            None
# 2         chyzryth@gmail.com                Lainnya            None
#
#   id_admin_fo status_kontak tanggal_kontak_pertama tanggal_kontak_terakhir
# 0        None        joined                   None     2025-09-18 17:39:40
# 1        None        joined                   None     2025-09-23 16:25:14
# 2        None        joined                   None     2025-10-03 09:48:34
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: CALON_SISWA]
# --------------------------------------------------
#    id_calon kode_unik             nama_lengkap  id_kontak_prospek  \
# 0         1  PIJWREZC     Daria Azmiya Jasmine                  1
# 1         2  LEHUEB6B  Annisa Zahro Ramadhania                  2
# 2         3  HBJ6O8TF     Zulfa Bariatur Rahma                  3
#
#   nama_panggilan jenis_kelamin tempat_lahir tanggal_lahir kewarganegaraan  \
# 0          Daria     Perempuan         None          None       Indonesia
# 1         Annisa     Perempuan         None          None       Indonesia
# 2          Zulfa     Perempuan         None          None       Indonesia
#
#                        email  ... fo_status fo_status_updated_at handover_at  \
# 0  puterihapsari.f@gmail.com  ...  new_lead                 None        None
# 1         dwirohm4@gmail.com  ...  new_lead                 None        None
# 2         chyzryth@gmail.com  ...  new_lead                 None        None
#
#   link_form_sent_at form_completed_at first_submitted_at latest_submitted_at  \
# 0              None              None               None                None
# 1              None              None               None                None
# 2              None              None               None                None
#
#   deleted_at created_at           updated_at
# 0       None       None  2025-09-18 17:39:40
# 1       None       None  2025-09-23 16:25:14
# 2       None       None  2025-10-03 09:48:34
#
# [3 rows x 34 columns]
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: CALON_SISWA_AKADEMIK]
# --------------------------------------------------
#    id_calon_akademik  id_calon          nama_sekolah jenjang_kelas_1  \
# 0                  1         1       TK Al Maghfirah              TK
# 1                  2         2  SD Khadijah Wonorejo              SD
# 2                  3         3      SMAN 17 Surabaya         SMA/SMK
#
#   jenjang_kelas_2 kurikulum_sekolah id_kursus id_periode id_level  \
# 0               B          Nasional    K00010       None     None
# 1               3         Cambridge    K00010       None     None
# 2              10          NASIONAL    K00014       None     None
#
#   submission_state  ... kemampuan_komputer kemampuan_software  \
# 0        submitted  ...               None               None
# 1        submitted  ...               None               None
# 2        submitted  ...       sudah pernah              Acode
#
#   penggunaan_gadget            sumber_info referensi  \
# 0              None  Teman/kerabat/saudara      None
# 1              None              Instagram      None
# 2  Handphone,Laptop                Lainnya      None
#
#                     alasan_daftar alasan_program harapan_program  \
# 0                            None           None            None
# 1  supaya lebih paham bhs Inggris           None            None
# 2                      UPSKILLING           None            None
#
#   lampiran_file               submitted_at
# 0          None 2026-06-23 19:57:48.304978
# 1          None 2026-06-23 19:57:48.304978
# 2          None 2026-06-23 19:57:48.304978
#
# [3 rows x 28 columns]
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: CALON_SISWA_ORTU]
# --------------------------------------------------
#    id_calon_ortu  id_calon nama_ayah pekerjaan_ayah pendidikan_ayah  \
# 0              1         1      None           None            None
# 1              2         2      None           None            None
# 2              3         3      None           None            None
#
#   penghasilan_ayah tempat_lahir_ayah tanggal_lahir_ayah nama_ibu  \
# 0             None                 -         1900-01-01     None
# 1             None                 -         1900-01-01     None
# 2             None                 -         1900-01-01     None
#
#   pekerjaan_ibu pendidikan_ibu penghasilan_ibu tempat_lahir_ibu  \
# 0          None           None            None             None
# 1          None           None            None             None
# 2          None           None            None             None
#
#   tanggal_lahir_ibu nama_wali pekerjaan_wali pendidikan_wali penghasilan_wali  \
# 0              None      None           None            None             None
# 1              None      None           None            None             None
# 2              None      None           None            None             None
#
#   tempat_lahir_wali tanggal_lahir_wali
# 0              None               None
# 1              None               None
# 2              None               None
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: CALON_SISWA_BAYAR]
# --------------------------------------------------
#    id_calon_bayar  id_calon_akademik nomor_invoice bank_pembayaran  \
# 0               1                  1          None         Mandiri
# 1               2                  2          None         Mandiri
# 2               3                  3          None            None
#
#   tanggal_konfirmasi_bayar bulan_mulai_belajar lokasi_belajar
# 0                     None           September            Sby
# 1                     None           September            Sby
# 2                     None                None           None
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: CALON_SISWA_JADWAL]
# --------------------------------------------------
#    id_calon_jadwal  id_calon_akademik tanggal_kontak_awal tanggal_wawancara  \
# 0                1                  1          2025-09-15              None
# 1                2                  2          2025-09-16        2025-09-16
# 2                3                  3          2025-09-16              None
#
#   tanggal_pembayaran tanggal_masuk tanggal_keluar
# 0               None    2025-09-24           None
# 1               None    2025-09-25           None
# 2               None          None           None
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: CALON_SISWA_KURSUS]
# --------------------------------------------------
#    id_calon_kursus  id_calon  urutan nama_kursus jenis_program
# 0                1         1       1          GE       English
# 1                2         2       2          GE       English
# 2                3         3       3         COD       Digital
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: CALON_SISWA_PROSES]
# --------------------------------------------------
#    id_calon_siswa_proses  id_calon_akademik admin_pengontak penanggung_jawab  \
# 0                      1                  1        Ibu Sari             None
# 1                      2                  2          Bu Dwi             None
# 2                      3                  3       Ibu Fitri             None
#
#   jenis_trial hasil_trial    waktu_trial_1    waktu_trial_2 tanggal_trial  \
# 0        None        None  0 days 00:00:00  0 days 00:00:00          None
# 1        None        None  0 days 15:45:00  0 days 00:00:00          None
# 2        None        None  0 days 00:00:00  0 days 00:00:00          None
#
#   laporan_trial  ...         hasil_penempatan followup_1 followup_2  \
# 0          None  ...  21 BALLOONS SR1 (QORIN)       None       None
# 1          None  ...   18 GOGO 1 SelK1 (TATA)       None       None
# 2          None  ...                     None       None       None
#
#   followup_3 akun_leapverse  wa_grup_leapverse  catatan_admin catatan_penting  \
# 0       None           None               None           None            None
# 1       None           None               None           None            None
# 2       None           None               None           None            None
#
#   keterangan_tambahan detail_lainnya
# 0                None           None
# 1                None           None
# 2                None           None
#
# [3 rows x 27 columns]
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: PEMINJAMAN]
# --------------------------------------------------
#    id_pinjam tanggal_pinjam  \
# 0          2     2023-06-11
# 1          3     2023-06-11
# 2          5     2023-08-21
#
#                                            keperluan id_user status_pinjam  \
# 0  <p>pinjam kamera - fun class tk mitra - 1 - 11...  U00026       Selesai
# 1  <p>1. kamera - fun class TK mitra - 1 - 11 Jun...  U00026       Selesai
# 2  <p>1. Tablet Leap - 1 - Jaga-jaga untuk Mid Te...  U00026       Selesai
#
#   catatan_sarpras          created_at
# 0                 2023-06-12 13:20:39
# 1                 2023-06-12 13:21:35
# 2                 2023-08-16 15:01:55
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: PENGADAAN]
# --------------------------------------------------
#    id_pengadaan                                          deskripsi  \
# 0            18  <p><span style="font-family: Arial; font-size:...
# 1            20  <p>"KABEL TELEPON</p>\r\n<p>kabel roset telepo...
# 2            21  <p>15 pcs Sarung kursi untuk Lab Komputer (10 ...
#
#                                           url_produk id_user status_pengajuan  \
# 0  https://docs.google.com/spreadsheets/d/1B0sVeV...  U00012          Selesai
# 1  https://docs.google.com/spreadsheets/d/1B0sVeV...  U00012          Selesai
# 2  https://docs.google.com/spreadsheets/d/1Onr3rr...  U00001          Selesai
#
#   catatan_admin   tanggal_pengajuan tanggal_selesai  \
# 0               2023-07-06 11:14:15             NaT
# 1               2023-08-03 09:36:19             NaT
# 2               2023-08-22 09:58:34             NaT
#
#                                        url_pembelian
# 0  https://docs.google.com/spreadsheets/d/15Xuh2Z...
# 1  https://docs.google.com/spreadsheets/d/15Xuh2Z...
# 2  https://docs.google.com/spreadsheets/d/15Xuh2Z...
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: PROBLEM]
# --------------------------------------------------
#    id_problem                                     detail_masalah id_user  \
# 0          43      AC Kelas Miss Erika kurang dingin ( belakang   U00012
# 1          58      Boya/mic untuk kelas hybrid tidak berfungsi (  U00026
# 2          60  tegangan listrik di ruang kelas belakang dapur...  U00033
#
#   status_perbaikan       tanggal_lapor tanggal_selesai  \
# 0           Proses 2023-06-28 16:07:52             NaT
# 1    Terselesaikan 2023-07-06 10:45:03      2023-07-17
# 2    Terselesaikan 2023-07-13 16:59:57      2023-08-10
#
#                                      catatan_teknisi gambar_problem
# 0  sudah info ke Pak Irawan,\r\nTukang AC masih l...           None
# 1                                                              None
# 2                               pemberian stabilizer           None
# --------------------------------------------------------------------------------
#
# 🚨 [🔴 DIAGNOSTIK TABEL ERROR: SOP] 🚨
# Pesan Sistem: ⚠️ sop: TER-SKIP! Dikirim 4 baris, tapi yang masuk DB HANYA 0 baris.
# --------------------------------------------------
# Berikut cuplikan data yang kemungkinan ditolak MySQL (Cek FK dan Tipe Data):
#                                     judul_sop  \
# 0  Akhir Penggunaan Kelas English (19.15 WIB)
# 1                      Penerimaan Surat Masuk
# 2                      Pengajuan Surat Keluar
# 3                       Pengajuan Surat Tugas
#
#                                     link_dokumen_sop          created_at  \
# 0  https://drive.google.com/file/d/1V0MpB7ctzPHe6... 2023-07-07 08:52:48
# 1  https://drive.google.com/file/d/1G8lO33yU7MufC... 2023-11-22 15:27:06
# 2  https://drive.google.com/file/d/14I7wYSk62WJAv... 2023-11-22 15:27:55
# 3  https://drive.google.com/file/d/1R-wKFqQeVSz62... 2023-11-22 15:28:27
#
#    id_sop_kategori
# 0                1
# 1                2
# 2                2
# 3                2
# Tipe data Pandas untuk tabel 'sop':
# judul_sop                   object
# link_dokumen_sop            object
# created_at          datetime64[ns]
# id_sop_kategori              int64
# dtype: object
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: SURAT_KELUAR]
# --------------------------------------------------
#    id_sk id_user                                      keterangan_sk  \
# 0     24  U00011  Surat Permohonan Uji Kompetensi dan Penggunaan...
# 1     26  U00011                                  Beasiswa Siswa GE
# 2     27  U00011  PERJANJIAN KERJASAMA / MEMORANDUM OF UNDERSTAN...
#
#                                      link_dokumen_sk     status_sk  \
# 0  https://docs.google.com/document/d/1xyhc4T-FlR...  Sudah Revisi
# 1  https://docs.google.com/document/d/1jMTK_3b57e...     Disetujui
# 2  https://docs.google.com/document/d/1Edeb7hWaBq...     Disetujui
#
#                                nomor_sk  \
# 0  090A/LEAP/IX/2023- 090B/LEAP/IX/2023
# 1                    101/LEAP/BD/X/2023
# 2                    102/LEAP/BD/X/2023
#
#                                           catatan_sk          created_at
# 0  Lengkapi Tanggal Pelaksanaan dengan tanggal ya... 2023-09-11 17:57:49
# 1                                  Tidak ada catatan 2023-10-25 16:57:38
# 2                                  Tidak ada catatan 2023-10-26 17:37:59
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: VERIFIKASI_SURAT_KELUAR]
# --------------------------------------------------
#    id_sk status_verifikasi_sk catatan_verifikasi_sk          created_at
# 0   <NA>             Diajukan     Tidak ada catatan 2023-06-12 13:32:50
# 1   <NA>             Diajukan     Tidak ada catatan 2023-06-12 13:33:07
# 2   <NA>             Diajukan     Tidak ada catatan 2023-06-12 14:28:56
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: SURAT_TUGAS]
# --------------------------------------------------
#    id_st id_user                                              acara  \
# 0     20  U00015  Pertemuan rutin di bulan Juli 2023 forum Laras...
# 1     21  U00015                             Temu Warga RT 01 RW 08
# 2     22  U00016  TEDxSurabaya Translators:\r\n\r\n1. Simulasi C...
#
#                undangan waktu_acara  \
# 0          Larasdikdudi  2023-07-27
# 1  Pengurus RT 01/ RW08  2023-08-23
# 2          TEDxSurabaya  2023-09-15
#
#                                         lokasi_acara jenis_kegiatan  \
# 0       SMK Teknik PAL Surabaya Jalan Ujung Surabaya        Offline
# 1                                           Balai RW        Offline
# 2  Topic: Connect to TEDxSurabaya Join Zoom Meeti...         Online
#
#    status_st periode               nomor_st         catatan_st  \
# 0  Disetujui    None   023/LEAP/ST/VII/2023  Tidak ada catatan
# 1  Disetujui    None  024/LEAP/ST/VIII/2023  Tidak ada catatan
# 2  Disetujui    None  025/LEAP/ST/VIII/2023  Tidak ada catatan
#
#                                              link_st  \
# 0  https://docs.google.com/document/d/1rILu6FE8Bd...
# 1  https://docs.google.com/document/d/1OQxpdKYfDF...
# 2  https://docs.google.com/document/d/10Zi6g0R9RR...
#
#                                         link_laporan  \
# 0  https://docs.google.com/document/d/1IAhWT4XjbX...
# 1  https://docs.google.com/document/d/1XrvRmYckBw...
# 2  https://docs.google.com/document/d/1pa9G3E3eUa...
#
#             catatan_laporan keterangan_st catatan_pembatalan  \
# 0  done/laporan sudah diisi                Tidak ada catatan
# 1         Tidak ada catatan                Tidak ada catatan
# 2     laporan kegiatan done                Tidak ada catatan
#
#            created_at
# 0 2023-07-25 09:56:19
# 1 2023-08-22 17:43:48
# 2 2023-09-13 13:01:52
# --------------------------------------------------------------------------------
#
# 🚨 [🔴 DIAGNOSTIK TABEL ERROR: SURAT_TUGAS_ANGGOTA] 🚨
# Pesan Sistem: ⚠️ surat_tugas_anggota: TER-SKIP! Dikirim 304 baris, tapi yang masuk DB HANYA 260 baris.
# --------------------------------------------------
# Berikut cuplikan data yang kemungkinan ditolak MySQL (Cek FK dan Tipe Data):
#    id_st id_user
# 0      6  U00012
# 1      6  U00003
# 2      7  U00026
# 3      7  U00012
# 4      8  U00026
# Tipe data Pandas untuk tabel 'surat_tugas_anggota':
# id_st       int64
# id_user    object
# dtype: object
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: SOP_KATEGORI]
# --------------------------------------------------
#    id_sop_kategori nama_kategori_sop
# 0                1             Kelas
# 1                2           HR / GA
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: PENGAJUAN_KARYAWAN]
# --------------------------------------------------
#    id_pengajuan id_user                             posisi jumlah  \
# 0             4  U00016  Part-Time Offline English Teacher      2
# 1             8  U00014           Magang Sales & Marketing      1
# 2            10  U00014            Volunteer LeapXperience      1
#
#                                               syarat  \
# 0  <h5 class="t-20 mb3" style="box-sizing: border...
# 1  <p>1. Background pendidikan apa saja</p>\r\n<p...
# 2  <p>1. Mahasiswa dari berbagai jurusan (tingkat...
#
#                                           pertanyaan  \
# 0  <p>Info Jam Kerja dan Gaji :</p>\r\n<p>&nbsp;<...
# 1  <p>1. Komitmen kapan bisa mulai dan lama magan...
# 2  <p>1. Apakah bisa hadir offline ke Leap setiap...
#
#                                         alur_seleksi  \
# 0  <p>1. Mengisi form dan test melalui link: http...
# 1  <p>1. Seleksi administrasi</p>\r\n<p>2. Probin...
# 2  <p>Seleksi Administrasi &amp; Skill :</p>\r\n<...
#
#                                           daftar_tes    status  \
# 0  <p>Mempersiapkan bahan micro teaching (MT) onl...  Diterima
# 1  <p>1. Buatlah desain poster sederhana program ...  Diterima
# 2  <p>Tes sudah terintegrasi dalam tahap administ...  Diterima
#
#             created_at
# 0  2023-06-16 17:02:47
# 1  2023-07-04 13:52:25
# 2  2023-07-18 10:11:14
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: HISTORI_PENGAJUAN]
# --------------------------------------------------
#    id_verifikasi  id_pengajuan status_verifikasi_pengajuan  \
# 0             11             4                    Diajukan
# 1             16             8                    Diajukan
# 2             17             8                    Diterima
#
#                                              catatan           created_at
# 0                                               None  2023-06-16 17:02:47
# 1                                               None  2023-07-04 13:52:25
# 2  Mbak, mohon diinfokan untuk tes ini harus dila...  2023-07-04 14:13:49
# --------------------------------------------------------------------------------
#
# 🚨 [🔴 DIAGNOSTIK TABEL ERROR: PELAMAR] 🚨
# Pesan Sistem: ⚠️ pelamar: TER-SKIP! Dikirim 192 baris, tapi yang masuk DB HANYA 142 baris.
# --------------------------------------------------
# Berikut cuplikan data yang kemungkinan ditolak MySQL (Cek FK dan Tipe Data):
#    id_pelamar  id_pengajuan               email_pelamar  \
# 0           1          <NA>  ditari@leapsurabaya.sch.id
# 1           2          <NA>  hartikaharahap95@gmail.com
# 2           3          <NA>             admin@gmail.com
# 3           4          <NA>   nirmalapradnyas@gmail.com
# 4           5             8   nirmalapradnyas@gmail.com
#
#                               nama_lengkap nama_panggilan jenis_kelamin  \
# 0                                        -              -     Perempuan
# 1           Hartika Prawidaningrum Harahap           Tika     Perempuan
# 2                                    sdasd          sadas     Perempuan
# 3  Ni Putu Jayanti Nirmala Pradnya Santosa        Nirmala     Perempuan
# 4  Ni Putu Jayanti Nirmala Pradnya Santosa        Nirmala     Perempuan
#
#   tempat_lahir tanggal_lahir  \
# 0            -    1970-01-01
# 1     Sidoarjo    1970-01-01
# 2          asd    1970-01-01
# 3     Surabaya    1970-01-01
# 4     Surabaya    1970-01-01
#
#                                           alamat_ktp  \
# 0                                                  -
# 1  Perum Grand Surya Cluster Jupiter Blok D12/16 ...
# 2                                                asd
# 3         Bendul Merisi Permai blok C no 22 Surabaya
# 4         Bendul Merisi Permai blok C no 22 Surabaya
#
#                                      alamat_domisili  ... penggunaan_laptop  \
# 0                                                  -  ...      Tidak Pernah
# 1  Perum Grand Surya Cluster Jupiter Blok D12/16 ...  ...            Pernah
# 2                                               asda  ...      Tidak Pernah
# 3                                           Surabaya  ...      Tidak Pernah
# 4                                           Surabaya  ...            Pernah
#
#   skor_toefl ekspektasi_gaji  \
# 0          0             0.0
# 1        507       4550000.0
# 2        asd             0.0
# 3        517             0.0
# 4        517             0.0
#
#                                        tautan_berkas         alasan_resign  \
# 0                                                  -                     -
# 1  https://drive.google.com/open?id=1Z_FpilagwmNd...  sedang tidak bekerja
# 2                                                  -                     -
# 3                                                  -                     -
# 4  https://drive.google.com/file/d/1u8_ZrepEz7mEG...                     -
#
#   skor_iq                               foto_iq  \
# 0       0                                     -
# 1     100  1688095776_3de967eefe836d28e873.jpeg
# 2       0                                     -
# 3       0                                     -
# 4      94   1688617417_0765b3a992194874930b.png
#
#                             foto_minat                      foto_kepribadian  \
# 0                                    -                                     -
# 1  1688095993_b75d248ce60436d0d4a1.jpg  1688096006_bf7b1c0e082c6aaf5e67.jpeg
# 2                                    -                                     -
# 3                                    -                                     -
# 4  1688617538_60b8cc4bd0dd8da5c0b4.jpg   1688617547_8eb3154d5d4cb7210165.png
#
#             created_at
# 0  1970-01-01 00:00:00
# 1  2023-06-29 10:24:53
# 2  1970-01-01 00:00:00
# 3  1970-01-01 00:00:00
# 4  2023-07-05 11:17:01
#
# [5 rows x 43 columns]
# Tipe data Pandas untuk tabel 'pelamar':
# id_pelamar               int64
# id_pengajuan             Int64
# email_pelamar           object
# nama_lengkap            object
# nama_panggilan          object
# jenis_kelamin           object
# tempat_lahir            object
# tanggal_lahir           object
# alamat_ktp              object
# alamat_domisili         object
# nomor_wa                object
# akun_linkedin           object
# akun_instagram          object
# akun_facebook           object
# sosmed_lain             object
# spesifikasi_laptop      object
# internet                object
# kegiatan_sekarang       object
# rencana_karir           object
# mobilitas               object
# sumber_info             object
# siap_wfo                object
# tanggal_bergabung       object
# kategori_pelamar        object
# riwayat_kerja           object
# riwayat_pendidikan      object
# pengalaman_bidang       object
# wawasan                 object
# riwayat_kesehatan       object
# status_pernikahan       object
# kemampuan_ajar          object
# penguasaan_aplikasi     object
# aplikasi_lainnya        object
# penggunaan_laptop       object
# skor_toefl              object
# ekspektasi_gaji        float64
# tautan_berkas           object
# alasan_resign           object
# skor_iq                 object
# foto_iq                 object
# foto_minat              object
# foto_kepribadian        object
# created_at              object
# dtype: object
# --------------------------------------------------------------------------------
#
# 📂 [🟢 PREVIEW TABEL SUKSES: PELAMAR_KERJA]
# --------------------------------------------------
#    id_pelamar_kerja  id_pelamar              nama_perusahaan  \
# 0                 3         101           Coding Bee Academy
# 1                 4         180  Pusat Bahasa UINSA Surabaya
# 2                 5         183      PT Aku Pintar Indonesia
#
#                   periode                            jabatan  \
# 0               2021-2022                           Educator
# 1  2011 - sampai sekarang               Tutor Bahasa Inggris
# 2               2019-2021  Tutor Team Lead dan English Tutor
#
#                                      deskripsi_kerja
# 0  <p>- Membuat lesson plan</p>\r\n<p>- Membuat s...
# 1  <p>Mengajar dua kelas pada semester 1 dan 2. D...
# 2  <p><span style="color: rgba(0, 0, 0, 0.9); fon...
# --------------------------------------------------------------------------------
#
# 🚨 [🔴 DIAGNOSTIK TABEL ERROR: PELAMAR_SEKOLAH] 🚨
# Pesan Sistem: ⚠️ pelamar_sekolah: TER-SKIP! Dikirim 53 baris, tapi yang masuk DB HANYA 51 baris.
# --------------------------------------------------
# Berikut cuplikan data yang kemungkinan ditolak MySQL (Cek FK dan Tipe Data):
#    id_pelamar_sekolah  id_pelamar                                nama_sekolah  \
# 0                <NA>         101                                 SDN Ranggeh
# 1                <NA>         180                              UINSA Surabaya
# 2                <NA>         183                 UNIVERSITAS NEGERI SURABAYA
# 3                <NA>         150  UNIVERSITAS NEGERI SEBELAS MARET SURAKARTA
# 4                <NA>         185              SMAK Kolese Santo Yusup Malang
#
#             jenjang                                       prodi  tahun_lulus  \
# 0                SD                                           -         2000
# 1  Universitas (S1)                              Sastra Inggris         2000
# 2  Universitas (S1)  PENDIDIKAN BAHASA INGGRIS / BAHASA INGGRIS         2000
# 3        Akademi D3                          KOMUNIKASI TERAPAN         2000
# 4               SMA                                      Bahasa         2000
#
#    ipk                                         organisasi
# 0  0.0                                                  -
# 1  0.0                                               PMII
# 2  0.0  SKI (Sie Kerohanian Islam)\r\nKepanitiaan Faku...
# 3  0.0                                         BEM, KAMMI
# 4  0.0
# Tipe data Pandas untuk tabel 'pelamar_sekolah':
# id_pelamar_sekolah      Int64
# id_pelamar              Int64
# nama_sekolah           object
# jenjang                object
# prodi                  object
# tahun_lulus             int64
# ipk                   float64
# organisasi             object
# dtype: object
# --------------------------------------------------------------------------------
#
# 🚨 [🔴 DIAGNOSTIK TABEL ERROR: PELAMAR_KURSUS] 🚨
# Pesan Sistem: ⚠️ pelamar_kursus: TER-SKIP! Dikirim 50 baris, tapi yang masuk DB HANYA 49 baris.
# --------------------------------------------------
# Berikut cuplikan data yang kemungkinan ditolak MySQL (Cek FK dan Tipe Data):
#    id_pelamar_kursus  id_pelamar                             nama_kursus  \
# 0                  3         101                            Data Science
# 1                  4         180                    Teachers development
# 2                  6         150  MAHIR MICROSOFT EXCEL DAN GOOGLE SHEET
# 3                  7         179   Online IELTS Writing Premium Batch 61
# 4                  8         191                     Diklat Samisanov 70
#
#       tanggal                                          deskripsi  \
# 0  1970-01-01                       <p>Belajar python pemula</p>
# 1  1970-01-01  <p>Teaching management, sistem TMS, cara menge...
# 2  1970-01-01             <p>Persyaratan masuk kerja di LEAP</p>
# 3  1970-01-01  <p>Workshop "IELTS Writing" yang diadakan oleh...
# 4  1970-01-01  <p>Diklat 40 JP dengan judul:</p>\r\n<p>Memanf...
#
#                              lokasi         nomor_sertifikat
# 0                            Online             184617619842
# 1                    UINSA Surabaya         000 - 756 - 458.
# 2  LEAP ENGLISH & DIGITAL, SURABAYA                  TDK ADA
# 3                     Zoom (Online)                        -
# 4                            online  021.1/K21/11164/VI.2023
# Tipe data Pandas untuk tabel 'pelamar_kursus':
# id_pelamar_kursus     Int64
# id_pelamar            Int64
# nama_kursus          object
# tanggal              object
# deskripsi            object
# lokasi               object
# nomor_sertifikat     object
# dtype: object
# --------------------------------------------------------------------------------
#
# 🚨 [🔴 DIAGNOSTIK TABEL ERROR: PROGRES_PELAMAR] 🚨
# Pesan Sistem: ⚠️ progres_pelamar: TER-SKIP! Dikirim 403 baris, tapi yang masuk DB HANYA 304 baris.
# --------------------------------------------------
# Berikut cuplikan data yang kemungkinan ditolak MySQL (Cek FK dan Tipe Data):
#    id_progres_pelamar  id_pelamar id_user status_progres_pelamar  \
# 0                  11         177  U00001              Interview
# 1                  12         177  U00012              Interview
# 2                  13         177  U00001              Interview
# 3                  14         178  U00001             Tahap Test
# 4                  15         178  U00001              Interview
#
#             catatan                                        tautan_file  \
# 0                    https://drive.google.com/drive/folders/17AhJjH...
# 1    <p>testing</p>                                                  -
# 2   <p>aku coba</p>                                                  -
# 3  <p>interview</p>  https://drive.google.com/drive/folders/1WYB9iR...
# 4
#
#   pertanyaan           created_at
# 0          -  2023-05-29 16:56:05
# 1          -  2023-05-29 16:57:22
# 2          -  2023-05-29 16:59:34
# 3          -  2023-05-29 17:45:09
# 4          -  2023-05-30 06:21:30
# Tipe data Pandas untuk tabel 'progres_pelamar':
# id_progres_pelamar         Int64
# id_pelamar                 Int64
# id_user                   object
# status_progres_pelamar    object
# catatan                   object
# tautan_file               object
# pertanyaan                object
# created_at                object
# dtype: object
# --------------------------------------------------------------------------------
#
# 🚨 [🔴 DIAGNOSTIK TABEL ERROR: REKRUTMEN_PELAMAR] 🚨
# Pesan Sistem: ⚠️ rekrutmen_pelamar: TER-SKIP! Dikirim 281 baris, tapi yang masuk DB HANYA 215 baris.
# --------------------------------------------------
# Berikut cuplikan data yang kemungkinan ditolak MySQL (Cek FK dan Tipe Data):
#    id_rekrutmen  id_pelamar id_user
# 0            10           5  U00014
# 1            12           2  U00014
# 2            13           2  U00023
# 3            20          12  U00014
# 4            21          12  U00016
# Tipe data Pandas untuk tabel 'rekrutmen_pelamar':
# id_rekrutmen     Int64
# id_pelamar       Int64
# id_user         object
# dtype: object
# --------------------------------------------------------------------------------
#
# ================================================================================
# 🏁 PROSES INSPEKSI SELESAI. SILAKAN CEK HASIL DIAGNOSTIK DI ATAS 🏁
# ================================================================================

# %%
# print("================================================================================")
# print(" 🧹 MEMULAI PROSES TRUNCATE DATA GLOBAL - FASE 1 (SISTEM RINGKASAN ATAS) 🧹 ")
# print("================================================================================")

# def truncate_tables_with_summary(db_connection, cursor, ordered_list):
#     truncate_results = {}
    
#     try:
#         # 🔥 SAKTI 1: Matikan benteng Foreign Key checks agar MySQL tidak memblokir penghapusan
#         cursor.execute("SET FOREIGN_KEY_CHECKS=0")
#         db_connection.commit()
#         print("🔓 Sensor Foreign Key Checks berhasil DIMATIKAN sementara.\n")
#     except Exception as e:
#         print(f"✗ Gagal mematikan Foreign Key Checks: {e}")
#         return
        
#     # ----------------------------------------------------------------------------
#     # SUB-LANGKAH A: PROSES EKSEKUSI TRUNCATE DI BELAKANG LAYAR
#     # ----------------------------------------------------------------------------
#     for table_name in ordered_list:
#         try:
#             truncate_query = f"TRUNCATE TABLE `{table_name}`"
#             cursor.execute(truncate_query)
#             db_connection.commit()
            
#             truncate_results[table_name] = {
#                 'status': 'success',
#                 'msg': f"✓ {table_name}: Sukses dibersihkan total! Seluruh baris data amblas."
#             }
#         except Exception as e:
#             db_connection.rollback()
#             truncate_results[table_name] = {
#                 'status': 'failed',
#                 'msg': f"✗ {table_name}: Gagal dikosongkan! Alasan: {e}"
#             }

#     try:
#         # 🔥 SAKTI 2: Wajib nyalakan kembali benteng Foreign Key checks setelah selesai
#         cursor.execute("SET FOREIGN_KEY_CHECKS=1")
#         db_connection.commit()
#         print("🔒 Sensor Foreign Key Checks berhasil DIHIDUPKAN kembali dengan aman.")
#     except Exception as e:
#         print(f"⚠️ Peringatan: Gagal menghidupkan kembali Foreign Key Checks: {e}")

#     # ----------------------------------------------------------------------------
#     # 🔥 CETAK PAPAN RINGKASAN TRUNCATE DI PALING ATAS (ANTI-SCROLL BOARD)
#     # ----------------------------------------------------------------------------
#     print("\n================================================================================")
#     print(" 📊 PAPAN RINGKASAN STATUS TRUNCATE DATABASE (CLEANUP SUMMARY BOARD) 📊")
#     print("================================================================================")
#     for table_name in ordered_list:
#         if table_name in truncate_results:
#             print(truncate_results[table_name]['msg'])
#         else:
#             print(f"⚠️  {table_name}: Lewat dari antrean pembersihan.")
#     print("================================================================================")
    
#     return truncate_results

# # === JALANKAN EKSEKUSI PEMBERSIHAN MENGGUNAKAN DAFTAR TABEL SALING SILANGMU ===
# results_truncate_fase_3 = truncate_tables_with_summary(
#     db_connection=db_new, 
#     cursor=cursor_new, 
#     ordered_list=tables_to_insert_ordered  # Otomatis memakai list urutan saling silang yang kita buat tadi
# )
